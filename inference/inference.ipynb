# %% [markdown]
# # Inference

# %% [markdown]
# ## 1. Import Libraries

# %%
import pandas as pd
import numpy as np
import pickle

# %% [markdown]
# ## 2. Pipeline Load

# %%
with open('pipeline.pkl','rb') as file_1:
    pipeline = pickle.load(file_1)

# %%
pipeline
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('scaler_n',
#                                                                    MinMaxScaler())]),
#                                                   ['MaxTemp', 'Rainfall',
#                                                    'Evaporation', 'Sunshine',
#                                                    'WindGustSpeed',
#                                                    'Humidity9am', 'Humidity3pm',
#                                                    'Pressure9am', 'Pressure3pm',
#                                                    'Cloud9am', 'Cloud3pm',
#                                                    'Temp3pm']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('encoder',
# ...

# %% [markdown]
# ## 3. Data Inference

# %%
data_inf ={
 'Location': {4183: 'Cobar', 4185: 'Cobar',  4186: 'Cobar',  4187: 'Cobar',  4188: 'Cobar'},
 'MaxTemp': {4183: 35.2, 4185: 36.1, 4186: 34.0, 4187: 34.2, 4188: 35.5},
 'Rainfall': {4183: 0.0, 4185: 0.0, 4186: 0.0, 4187: 0.0, 4188: 0.0},
 'Evaporation': {4183: 12.0, 4185: 13.0, 4186: 9.8, 4187: 14.6, 4188: 12.0},
 'Sunshine': {4183: 12.3, 4185: 0.0, 4186: 12.6, 4187: 13.2, 4188: 12.3},
 'WindGustDir': {4183: 'SSW', 4185: 'N', 4186: 'SSW', 4187: 'SE', 4188: 'ENE'},
 'WindGustSpeed': {4183: 48.0, 4185: 43.0, 4186: 41.0, 4187: 37.0, 4188: 48.0},
 'WindDir9am': {4183: 'ENE', 4185: 'N', 4186: 'S', 4187: 'SE', 4188: 'ENE'},
 'WindDir3pm': {4183: 'SW', 4185: 'WNW', 4186: 'SSE', 4187: 'S', 4188: 'WSW'},
 'Humidity9am': {4183: 20.0, 4185: 26.0, 4186: 33.0, 4187: 25.0, 4188: 46.0},
 'Humidity3pm': {4183: 13.0, 4185: 19.0, 4186: 15.0, 4187: 9.0, 4188: 28.0},
 'Pressure9am': {4183: 1006.3,
  4185: 1007.7,
  4186: 1011.3,
  4187: 1013.3,
  4188: 1008.3},
 'Pressure3pm': {4183: 1004.4,
  4185: 1007.4,
  4186: 1009.9,
  4187: 1009.2,
  4188: 1004.0},
 'Cloud9am': {4183: 2.0, 4185: 8.0, 4186: 3.0, 4187: 1.0, 4188: 1.0},
 'Cloud3pm': {4183: 5.0, 4185: 8.0, 4186: 1.0, 4187: 1.0, 4188: 5.0},
 'Temp3pm': {4183: 33.4, 4185: 34.3, 4186: 31.5, 4187: 32.8, 4188: 33.3},
 'RainToday': {4183: 'No', 4185: 'No', 4186: 'No', 4187: 'No', 4188: 'No'},
 'RainTomorrow': {4183: 0, 4185: 0, 4186: 0, 4187: 0, 4188: 0}}

data_inf = pd.DataFrame(data_inf)
data_inf
# Out:
#      Location  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 4183    Cobar     35.2       0.0         12.0      12.3         SSW
# 4185    Cobar     36.1       0.0         13.0       0.0           N
# 4186    Cobar     34.0       0.0          9.8      12.6         SSW
# 4187    Cobar     34.2       0.0         14.6      13.2          SE
# 4188    Cobar     35.5       0.0         12.0      12.3         ENE
#
#       WindGustSpeed WindDir9am WindDir3pm  Humidity9am  Humidity3pm  \
# 4183           48.0        ENE         SW         20.0         13.0
# 4185           43.0          N        WNW         26.0         19.0
# 4186           41.0          S        SSE         33.0         15.0
# 4187           37.0         SE          S         25.0          9.0
# 4188           48.0        ENE        WSW         46.0         28.0
#
#       Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp3pm RainToday  \
# 4183       1006.3       1004.4       2.0       5.0     33.4        No
# ...

# %% [markdown]
# ## 4. Predict

# %%
y_pred_inf = pipeline.predict(data_inf)
y_pred_inf
# Out:
# array([0, 0, 0, 0, 0], dtype=int64)

# %% [markdown]
# ## 5. Concatenate Prediction

# %%
data_inf['PredictRain'] = y_pred_inf
data_inf
# Out:
#      Location  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 4183    Cobar     35.2       0.0         12.0      12.3         SSW
# 4185    Cobar     36.1       0.0         13.0       0.0           N
# 4186    Cobar     34.0       0.0          9.8      12.6         SSW
# 4187    Cobar     34.2       0.0         14.6      13.2          SE
# 4188    Cobar     35.5       0.0         12.0      12.3         ENE
#
#       WindGustSpeed WindDir9am WindDir3pm  Humidity9am  Humidity3pm  \
# 4183           48.0        ENE         SW         20.0         13.0
# 4185           43.0          N        WNW         26.0         19.0
# 4186           41.0          S        SSE         33.0         15.0
# 4187           37.0         SE          S         25.0          9.0
# 4188           48.0        ENE        WSW         46.0         28.0
#
#       Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp3pm RainToday  \
# 4183       1006.3       1004.4       2.0       5.0     33.4        No
# ...
